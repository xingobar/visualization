# %%
# https://www.kaggle.com/anokas/2015-us-traffic-fatalities
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
accidents = pd.read_csv('/Users/xingobar/Downloads/ACC_AUX.CSV')

# %%
accidents.head(5)
# Out:
#    YEAR  STATE  ST_CASE  COUNTY  FATALS  A_CRAINJ  A_REGION  A_RU  A_INTER  \
# 0  2015      1    10001     127       1         1         4     1        2
# 1  2015      1    10002      83       1         1         4     1        1
# 2  2015      1    10003      11       1         1         4     1        2
# 3  2015      1    10004      45       1         1         4     1        2
# 4  2015      1    10005      45       1         1         4     2        2
#
#    A_RELRD    ...     A_D16_19  A_D15_20  A_D16_20  A_D65PLS  A_D21_24  \
# 0        4    ...            2         2         2         1         2
# 1        3    ...            2         2         2         2         2
# 2        4    ...            2         2         2         2         2
# 3        4    ...            2         2         2         2         2
# 4        1    ...            2         2         2         2         1
#
#    A_D16_24  A_RD  A_HR  A_DIST  A_DROWSY
# 0         2     1     2       2         2
# ...

# %%
state  = accidents.STATE.value_counts().sort_index()
FATALS = accidents.FATALS.value_counts().sort_index()
state_type = accidents.STATE.unique()
FATALS_type = accidents.FATALS.unique()

# %%
accidents.columns.tolist()
# Out:
# ['YEAR',
#  'STATE',
#  'ST_CASE',
#  'COUNTY',
#  'FATALS',
#  'A_CRAINJ',
#  'A_REGION',
#  'A_RU',
#  'A_INTER',
#  'A_RELRD',
#  'A_INTSEC',
#  'A_ROADFC',
#  'A_JUNC',
#  'A_MANCOL',
#  'A_TOD',
#  'A_DOW',
#  'A_CT',
#  'A_LT',
#  'A_MC',
#  'A_SPCRA',
#  'A_PED',
#  'A_PED_F',
#  'A_PEDAL',
#  'A_PEDAL_F',
#  'A_ROLL',
#  'A_POLPUR',
#  'A_POSBAC',
#  'A_D15_19',
#  'A_D16_19',
#  'A_D15_20',
#  'A_D16_20',
#  'A_D65PLS',
#  'A_D21_24',
#  'A_D16_24',
#  'A_RD',
#  'A_HR',
#  'A_DIST',
#  'A_DROWSY']

# %%
plt.figure(figsize=(18,10))
fig,ax = plt.subplots(1,1)
for i in range(1,11):
    accidents['A_REGION'].value_counts().sort_index().plot(kind='bar')
plt.xlabel('A_REGION')
plt.ylabel('Total accident')
plt.title('The total accident of region')

# %%
accidents.A_REGION.value_counts()
# Out:
# 4     6602
# 6     5259
# 5     4490
# 9     3821
# 3     3543
# 2     2670
# 7     2096
# 8     1413
# 10    1390
# 1      882
# Name: A_REGION, dtype: int64

# %%
plt.figure(figsize=(18,10))
fig,ax = plt.subplots(1,1)
accidents['FATALS'].value_counts().sort_index().plot(kind='barh')
ax.set_ylabel('FATALS type')
ax.set_xlabel('Total')
plt.title('The total of FATALS within types')

# %%
people = pd.read_csv('/Users/xingobar/Downloads/PER_AUX.CSV')

# %%
people.head()
# Out:
#    A_AGE1  A_AGE2  A_AGE3  A_AGE4  A_AGE5  A_AGE6  A_AGE7  A_AGE8  A_AGE9  \
# 0       4       5      11       7       8       8      10       6       2
# 1       3       5       9       6       6       6       8       4       2
# 2       3       4       7       4       4       4       6       3       2
# 3       2       2       5       2       2       2       4       2       2
# 4       3       5       8       5       5       5       7       4       2
#
#    ST_CASE  ...    YEAR  A_PTYPE  A_REST  A_ALCTES  A_HISP  A_RCAT  A_HRACE  \
# 0    10001  ...    2015        1       2         2       1       1        2
# 1    10002  ...    2015        1       2         1       1       1        2
# 2    10003  ...    2015        1       2         2       1       2        3
# 3    10003  ...    2015        2       2         3       0       0        0
# 4    10004  ...    2015        1       2         2       1       1        2
#
#    A_EJECT  A_PERINJ  A_LOC
# 0        1         1      1
# ...

# %%
people.columns.tolist()
# Out:
# ['A_AGE1',
#  'A_AGE2',
#  'A_AGE3',
#  'A_AGE4',
#  'A_AGE5',
#  'A_AGE6',
#  'A_AGE7',
#  'A_AGE8',
#  'A_AGE9',
#  'ST_CASE',
#  'VEH_NO',
#  'PER_NO',
#  'YEAR',
#  'A_PTYPE',
#  'A_REST',
#  'A_ALCTES',
#  'A_HISP',
#  'A_RCAT',
#  'A_HRACE',
#  'A_EJECT',
#  'A_PERINJ',
#  'A_LOC']

# %%
columns = ['A_AGE' + str(i) for i in range(1,10)]
for column in columns:
    plt.title('%s distribution within type' % (column))
    for i in range(1,6):
        people[column][people.A_PTYPE == i].plot(kind='kde')
    plt.legend(('type1','type2','type3','type4','type5'),loc='best')
    if column != 'A_AGE9' :
        plt.subplots(1,1)

# %%
people.ST_CASE.unique()
# Out:
# array([ 10001,  10002,  10003, ..., 560128, 560129, 560130])

# %%
accidents.ST_CASE.unique()
# Out:
# array([ 10001,  10002,  10003, ..., 560128, 560129, 560130])

# %%
# Out:
#        YEAR  STATE  ST_CASE  COUNTY  FATALS  A_CRAINJ  A_REGION  A_RU  \
# 0      2015      1    10001     127       1         1         4     1
# 1      2015      1    10002      83       1         1         4     1
# 2      2015      1    10003      11       1         1         4     1
# 3      2015      1    10004      45       1         1         4     1
# 4      2015      1    10005      45       1         1         4     2
# 5      2015      1    10006     111       1         1         4     1
# 6      2015      1    10007      89       1         1         4     2
# 7      2015      1    10008      73       1         1         4     2
# 8      2015      1    10009     117       1         1         4     2
# 9      2015      1    10010      33       1         1         4     1
# 10     2015      1    10011      83       1         1         4     2
# 11     2015      1    10012      95       1         1         4     2
# ...

# %%
vehicle = pd.read_csv('/Users/xingobar/Downloads/VEH_AUX.CSV')
