# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import colorsys
# %matplotlib inline

# %%
df = pd.read_csv('/Users/xingobar/Downloads/2016-FCC-New-Coders-Survey-Data.csv')
# Out:
# //anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (21,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber       ...       ResourceSoloLearn  \
# ...

# %% [markdown]
# # Age

# %%
fig,ax = plt.subplots(figsize=(10,10))
plt.title('Age distribution',fontsize=15)
plt.hist(df['Age'].dropna(),bins=15,color = "#ffcc80",alpha=0.7,label='Age')
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Age',fontsize=15)
plt.setp(ax.get_xticklabels(),fontsize=15)
plt.setp(ax.get_yticklabels(),fontsize=15)
plt.legend(loc='best',fontsize='x-large')
plt.show()

# %%
print df.columns.tolist()
# Out:
# ['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter', 'BootcampLoanYesNo', 'BootcampMonthsAgo', 'BootcampName', 'BootcampPostSalary', 'BootcampRecommend', 'ChildrenNumber', 'CityPopulation', 'CodeEventBootcamp', 'CodeEventCoffee', 'CodeEventConferences', 'CodeEventDjangoGirls', 'CodeEventGameJam', 'CodeEventGirlDev', 'CodeEventHackathons', 'CodeEventMeetup', 'CodeEventNodeSchool', 'CodeEventNone', 'CodeEventOther', 'CodeEventRailsBridge', 'CodeEventRailsGirls', 'CodeEventStartUpWknd', 'CodeEventWomenCode', 'CodeEventWorkshop', 'CommuteTime', 'CountryCitizen', 'CountryLive', 'EmploymentField', 'EmploymentFieldOther', 'EmploymentStatus', 'EmploymentStatusOther', 'ExpectedEarning', 'FinanciallySupporting', 'Gender', 'HasChildren', 'HasDebt', 'HasFinancialDependents', 'HasHighSpdInternet', 'HasHomeMortgage', 'HasServedInMilitary', 'HasStudentDebt', 'HomeMortgageOwe', 'HoursLearning', 'ID.x', 'ID.y', 'Income', 'IsEthnicMinority', 'IsReceiveDiabilitiesBenefits', 'IsSoftware
# ...

# %% [markdown]
# # Gender population

# %%
labels = df['Gender'].value_counts().index
fig,ax = plt.subplots(figsize=(10,10))
colors = ['#f4511e','#00acc1','#4caf50','#fb8c00','#9575cd']
patches, texts, autotexts = plt.pie(df['Gender'].value_counts(), autopct='%1.1f%%', 
                                    shadow=True, startangle=90,colors=colors)

### fontsize
for idx in xrange(len(autotexts)):
    autotexts[idx].set_fontsize(15)

plt.legend(labels,fontsize='x-large',loc='best', bbox_to_anchor=(1.05,1),frameon=True)
plt.title('Gender',fontsize=15)
plt.show()

# %% [markdown]
# # Employment Field

# %%
employment_field = df['EmploymentField'].value_counts().index
employment_counts = df['EmploymentField'].value_counts().values

# %%
fig,ax = plt.subplots(figsize=(10,10))
length = len(df.EmploymentField.value_counts().index)
HSV_tuples = [(x*1.0/length, 0.8, 0.8) for x in xrange(length)]
RGB = [colorsys.hsv_to_rgb(*i) for i in HSV_tuples]
patches, texts, autotexts = plt.pie(df['EmploymentField'].value_counts(), 
                                    autopct='%1.1f%%', shadow=True, startangle=90,colors=RGB)
### fontsize
for text in xrange(len(autotexts)):
    autotexts[text].set_fontsize(15)

#autotexts[0].set_fontsize(15)
plt.legend(employment_field,fontsize='x-large',loc='best', bbox_to_anchor=(1.05,1),frameon=True)
plt.title('EmploymentField',fontsize=15)
plt.show()

# %% [markdown]
# # Age Group

# %%
df['AgeGroup'] = pd.cut(df['Age'],[0,21,31,41,99],labels=['10-20','21-30','31-40','41+'],right=False)

# %%
fig,ax = plt.subplots(figsize=(10,10))
df['AgeGroup'].value_counts(sort=False).plot(kind='bar',ax=ax,rot=0)
plt.title('Age Distribution',fontsize=15)
plt.ylabel('Number of coder' , fontsize=15)
plt.xlabel('Age',fontsize=15)
ticks = plt.setp(ax.get_xticklabels(),fontsize=15)
ticks = plt.setp(ax.get_yticklabels(),fontsize=15)

# %% [markdown]
# # many young people are coder

# %% [markdown]
# # Month Programming

# %%
df['MonthsProgrammingGroup'] = pd.cut(df['MonthsProgramming'],[0,6,24,999],labels=['<6','6-24','24+'],right=False)
fig,ax = plt.subplots(figsize=(10,10))
df['MonthsProgrammingGroup'].value_counts(sort=False).plot(kind='bar',ax=ax,rot=0)
plt.title('Month Programming',fontsize=15)
plt.xlabel('Month Group',fontsize=15)
plt.ylabel('Number of coders',fontsize=15)
ticks = plt.setp(ax.get_xticklabels(),fontsize=15)
ticks = plt.setp(ax.get_yticklabels(),fontsize=15)

# %% [markdown]
# # Hours Learning

# %%
df['HoursLearningGroup'] = pd.cut(df['HoursLearning'],[0,6,13,24,999],labels=['<6','6-12','13-24','24+'])
fig,ax = plt.subplots(figsize=(10,10))
plt.title('Hours Learning',fontsize=15)
df['HoursLearningGroup'].value_counts(sort=False).plot(kind='bar',ax=ax,rot=0)
plt.ylabel('Number of coders',fontsize=15)
plt.xlabel('Hour Group',fontsize=15)
ticks = plt.setp(ax.get_xticklabels(),fontsize=15)
ticks = plt.setp(ax.get_yticklabels(),fontsize=15)

# %% [markdown]
# # MoneyForLearning

# %%
df['MoneyForLearningGroup'] = pd.cut(df['MoneyForLearning'],[0,500,1000,200000],labels=['<500','500-1000','1000+'])
fig,ax = plt.subplots(figsize=(10,5))
plt.title('MoneyForLearning',fontsize=15)
df['MoneyForLearningGroup'].value_counts(sort=False).plot(kind='bar',ax=ax,rot=0)
plt.ylabel('Number of coders',fontsize=15)
plt.xlabel('Money',fontsize=15)
ticks = plt.setp(ax.get_xticklabels(),fontsize=15)
ticks = plt.setp(ax.get_yticklabels(),fontsize=15)
#print df['MoneyForLearning'].unique()

# %% [markdown]
# # Current Income

# %%
plt.subplots(figsize=(10,10))
ax = sns.boxplot(data=df,x='AgeGroup',y='Income')
ax.set_ylabel('Income',fontsize=15)
ax.set_xlabel('AgeGroup',fontsize=15)
ax.set_title('Current Income vs Age',fontsize=15)
_ = plt.setp(ax.get_xticklabels(),fontsize=15)
_ = plt.setp(ax.get_yticklabels(),fontsize=15)
_ = ax.set_ylim(0,200000)
_ = ax.set_yticks(np.linspace(0, 200000, 11))

# %% [markdown]
# # Current Income vs Age and SoftwareDev

# %%
plt.subplots(figsize=(10,5))
ax = sns.boxplot(data=df , x='AgeGroup',y = 'Income',hue='IsSoftwareDev')
ax.set_ylabel('Income',fontsize=15)
ax.set_xlabel('AgeGroup',fontsize=15)
ax.set_title('Current Income vs Age and SoftwareDeveloper',fontsize=15)
_ = plt.setp(ax.get_xticklabels(),fontsize=15)
_ = plt.setp(ax.get_yticklabels(),fontsize=15)
_ = ax.set_ylim(df['Income'].min(),df['Income'].max())
_ = ax.set_yticks(np.linspace(0,200000,11))

# %% [markdown]
# # MonthGroup vs Income

# %%
plt.subplots(figsize=(10,10))
ax = sns.boxplot(data=df,x='MonthsProgrammingGroup',y='Income')
plt.title('MonthGroup vs Income',fontsize=15)
ax.set_ylabel('Income',fontsize=15)
ax.set_xlabel('MonthsProgrammingGroup',fontsize=15)
_ = plt.setp(ax.get_xticklabels(),fontsize=15)
_ = plt.setp(ax.get_yticklabels(),fontsize=15)
_ = ax.set_ylim(df['Income'].min(),df['Income'].max())
_ = ax.set_yticks(np.linspace(0,200000,11))

# %% [markdown]
# # Income vs Degree

# %%
plt.subplots(figsize=(10,5))
ax= sns.boxplot(data=df,x='Income',y='SchoolDegree',orient='h')
ax.set_ylabel('School Degree',fontsize=15)
ax.set_xlabel('Income',fontsize=15)
ax.set_title('Income vs Degree',fontsize=15)
_ = plt.setp(ax.get_xticklabels(),fontsize=15)
_ = plt.setp(ax.get_yticklabels(),fontsize=15)
_ = ax.set_xlim(df['Income'].min(),df['Income'].max())
_ = ax.set_xticks(np.linspace(0,200000,11))

# %% [markdown]
# # Income vs Employment Field

# %%
plt.subplots(figsize=(10,7))
ax = sns.boxplot(data=df,x='Income',y='EmploymentField',orient='h')
ax.set_ylabel('EmploymentField',fontsize=15)
ax.set_xlabel('Income',fontsize=15)
ax.set_title('Income vs EmploymentField',fontsize=15)
_ = plt.setp(ax.get_xticklabels(),fontsize=15)
_ = plt.setp(ax.get_yticklabels(),fontsize=15)
_ = ax.set_xlim(df['Income'].min(),df['Income'].max())
_ = ax.set_xticks(np.linspace(0,200000,11))

# %% [markdown]
# # Income vs Age and Gender

# %%
df['Genders'] = df.Gender.copy()
df.loc[df.Genders.isin(['genderqueer', 'trans', 'agender']) | df.Genders.isnull(), 
       'Genders'] = 'other/NA'

#df['Genders'] = df['Gender'].copy()
#df['Genders'] = df.loc[df['Genders'].isin(['genderqueer', 'trans', 'agender']) | 
#                       df['Genders'].isnull(),'Genders'] = 'other'
plt.subplots(figsize=(10,10))
plt.title('Income vs Age and Gender',fontsize=15)
ax = sns.boxplot(data=df,x='AgeGroup',y='Income',hue='Genders')
ax.set_ylabel('Income',fontsize=15)
ax.set_xlabel('AgeGroup',fontsize=15)
_ = plt.setp(ax.get_xticklabels(),fontsize=15)
_ = plt.setp(ax.get_yticklabels(),fontsize=15)
_ = ax.set_ylim(df['Income'].min(),df['Income'].max())
_ = ax.set_yticks(np.linspace(0,200000,11))
_ = plt.legend(fontsize='x-large',loc='best')

# %% [markdown]
# # Income vs City Size and Gender

# %%
plt.subplots(figsize=(10,7))
plt.title('Income vs City Size and Gender',fontsize=15)
ax = sns.boxplot(data=df,x='CityPopulation',y='Income',hue='Genders',order=['less than 100,000',
                                                                            'between 100,000 and 1 million',
                                                                            'more than 1 million'])
ax.set_ylabel('Income',fontsize=15)
ax.set_xlabel('City Size',fontsize=15)
_ = plt.setp(ax.get_xticklabels(),fontsize=15)
_ = plt.setp(ax.get_yticklabels(),fontsize=15)
_ = ax.set_ylim(df['Income'].min(),df['Income'].max())
_ = ax.set_yticks(np.linspace(0,200000,11))
_ = plt.legend(fontsize='x-large',loc='best')

# %% [markdown]
# # MoneyForLearningGroup vs Age

# %%
plt.subplots(figsize=(10,7))
plt.title('MoneyForLearningGroup vs Age',fontsize=15)
ax = sns.boxplot(data=df,x='MoneyForLearningGroup',y='Age')
ax.set_ylabel('Age',fontsize=15)
ax.set_xlabel('MoneyForLearningGroup',fontsize=15)
_ = plt.setp(ax.get_xticklabels(),fontsize=15)
_ = plt.setp(ax.get_yticklabels(),fontsize=15)
_ = ax.set_ylim(df['Age'].min(),df['Age'].max())

# %% [markdown]
# # Income vs MonthProgrammingGroup and AgeGroup

# %%
plt.subplots(figsize=(10,7))
plt.title('Income vs MonthProgrammingGroup and AgeGroup',fontsize=15)
ax = sns.boxplot(data=df,x='MonthsProgrammingGroup',y='Income',hue='AgeGroup')
ax.set_ylabel('Income',fontsize=15)
ax.set_xlabel('MonthsProgrammingGroup',fontsize=15)
_ = plt.setp(ax.get_xticklabels(),fontsize=15)
_ = plt.setp(ax.get_yticklabels(),fontsize=15)
_ = ax.set_ylim(df['Income'].min(),df['Income'].max())
_ = ax.set_yticks(np.linspace(0,200000,11))

# %% [markdown]
# # MonthProgramming vs School Degree

# %%
plt.subplots(figsize=(10,7))
plt.title('MonthProgramming vs School Degree',fontsize=15)
ax = sns.boxplot(data=df,y='SchoolDegree',x='MonthsProgramming',orient='h')
ax.set_ylabel('School Degree',fontsize=15)
ax.set_xlabel('MonthsProgramming',fontsize=15)
_ = plt.setp(ax.get_xticklabels(),fontsize=15)
_ = plt.setp(ax.get_yticklabels(),fontsize=15)
_ = ax.set_xlim(0,110)
